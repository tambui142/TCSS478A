# %%
#import pyBigWig
import numpy

#don't print (04,16)(09,20)///(12,16) (24,17)(13,20)(32,20)(17,29)(25,29)
for j in range (3, 47): #run outer loop from 3 to 46
    if(j==3):
         for i in range(16, 30): #loop from 16 to 29 
            if(i == 16 or i == 17 or i == 18 or i == 20 or i == 22 or i == 29):
                print("Trainning data")
#               exec("C03M%d = pyBigWig.open(\"/Users/gurchetan/Desktop/BioData/training/C03M%d.bigwig\")" %(i, i))
                print("j:%d i:%d" %(j, i))   
    if(j==4):
        for i in range(16, 30): #loop from 16 to 29 
            if(i == 16 or i == 17 or i == 18 or i == 20 or i == 22 or i == 29): 
                if(j==4 and i==16):
                    print("Valid data")
                    print("j:%d i:%d" %(j, i))
#                   exec("C04M%d = pyBigWig.open(\"/Users/gurchetan/Desktop/BioData/validation/C04M%d.bigwig\")" %(i, i))
                    print("***************************************************************")
                else:
                    print("Trainning data")
#                   exec("C04M%d = pyBigWig.open(\"/Users/gurchetan/Desktop/BioData/training/C04M%d.bigwig\")" %(i, i))
                    print("j:%d i:%d" %(j, i))
    if(j==9):       
        for i in range(16, 30): #loop from 16 to 29 
            if(i == 16 or i == 17 or i == 18 or i == 20 or i == 22 or i == 29): 
                if(j==9 and i==20):
                    print("Valid data")
                    print("j:%d i:%d" %(j, i))
#                   exec("C09M%d = pyBigWig.open(\"/Users/gurchetan/Desktop/BioData/validation/C09M%d.bigwig\")" %(i, i))
                    print("***************************************************************")
                else:
                    print("Trainning data")
#                   exec("C09M%d = pyBigWig.open(\"/Users/gurchetan/Desktop/BioData/training/C09M%d.bigwig\")" %(i, i))
                    print("j:%d i:%d" %(j, i)) 
                    
    if(j==12 or j==13 or j==17 or j==18 or j==23 or j==24 or j==25 or j==27 or j==32 or j==36 or j==46): #only go inside if matches our needs
        for i in range(16, 30): #loop from 16 to 29 
            if(i == 16 or i == 17 or i == 18 or i == 20 or i == 22 or i == 29): 
                if((j==12 and i==16) or (j==24 and i==17) or (j==13 and i == 20) or
                    (j== 32 and i==20) or (j==17 and i==29)):
                    print("Valid data")
                    print("j:%d i:%d" %(j, i))
#                   exec("C%dM%d = pyBigWig.open(\"/Users/gurchetan/Desktop/BioData/validation/C%dM%d.bigwig\")" %(j, i, j, i))
                    print("***************************************************************")
                if(j == 25 and i==29):
                    print("Missing data")
                    print("j:%d i:%d" %(j, i))
                    print("***************************************************************")
                else:
                    print("Trainning data")
#                   exec("C%dM%d = pyBigWig.open(\"/Users/gurchetan/Desktop/BioData/training/C%dM%d.bigwig\")" %(j, i, j, i))
                    print("j:%d i:%d" %(j, i))
# Out:
# Trainning data
# j:3 i:16
# Trainning data
# j:3 i:17
# Trainning data
# j:3 i:18
# Trainning data
# j:3 i:20
# Trainning data
# j:3 i:22
# Trainning data
# j:3 i:29
# Valid data
# j:4 i:16
# ***************************************************************
# Trainning data
# j:4 i:17
# Trainning data
# j:4 i:18
# Trainning data
# j:4 i:20
# Trainning data
# j:4 i:22
# Trainning data
# j:4 i:29
# Trainning data
# j:9 i:16
# Trainning data
# j:9 i:17
# Trainning data
# j:9 i:18
# Valid data
# j:9 i:20
# ***************************************************************
# Trainning data
# j:9 i:22
# Trainning data
# j:9 i:29
# Valid data
# j:12 i:16
# ***************************************************************
# Trainning data
# j:12 i:16
# Trainning data
# j:12 i:17
# Trainning data
# j:12 i:18
# Trainning data
# j:12 i:20
# Trainning data
# j:12 i:22
# Trainning data
# j:12 i:29
# Trainning data
# j:13 i:16
# Trainning data
# j:13 i:17
# Trainning data
# j:13 i:18
# Valid data
# ...
